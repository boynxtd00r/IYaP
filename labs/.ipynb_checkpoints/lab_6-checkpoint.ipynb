# %% [markdown]
# ### Задание 1 (наследование и перегрузка операторов)

# %%
class Str(str):
    def __lt__(self, other):
        if len(self) != len(other):
            return len(self) < len(other)
        return super().__lt__(other)

    def __le__(self, other):
        if len(self) != len(other):
            return len(self) <= len(other)
        return super().__le__(other)

    def __gt__(self, other):
        if len(self) != len(other):
            return len(self) > len(other)
        return super().__gt__(other)

    def __ge__(self, other):
        if len(self) != len(other):
            return len(self) >= len(other)
        return super().__ge__(other)

    def __eq__(self, other):
        return super().__eq__(other)

    def __ne__(self, other):
        return super().__ne__(other)

# %%
Str('ac') < Str('a')
# Out:
# False

# %%
Str('ac') > Str('a')
# Out:
# True

# %%
Str('ac') < Str('aba')
# Out:
# True

# %%
Str('ac') > Str('aba')
# Out:
# False

# %%
Str('ac').upper()
# Out:
# 'AC'

# %% [markdown]
# ### Задание 2 (полиморфизм и инкапсуляция)

# %%
import math

class Rectangle:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def get_perimeter(self):
        return 2 * (self.a + self.b)

    def get_square(self):
        return self.a * self.b


class Circle:
    def __init__(self, r):
        self.r = r

    def get_perimeter(self):
        return 2 * math.pi * self.r

    def get_square(self):
        return math.pi * self.r ** 2


class Rhombus:
    def __init__(self, p, q):
        self.p = p
        self.q = q

    def get_perimeter(self):
        side = math.sqrt((self.p / 2) ** 2 + (self.q / 2) ** 2)
        return 4 * side

    def get_square(self):
        return (self.p * self.q) / 2

# %%
rec = Rectangle(2, 3)
rec.get_perimeter(), rec.get_square()
# Out:
# (10, 6)

# %%
cir = Circle(3)
cir.get_perimeter(), cir.get_square()
# Out:
# (18.84955592153876, 28.274333882308138)

# %%
rhom = Rhombus(3, 4)
rhom.get_perimeter(), rhom.get_square()
# Out:
# (10.0, 6.0)

# %% [markdown]
# ### Задание 3 (наследование)

# %%
from collections import Counter

class MyCounter(Counter):
    def least_common(self, n=None):
        if n is None:
            return sorted(self.items(), key=lambda x: x[1])
        return sorted(self.items(), key=lambda x: x[1], reverse = True)

# %%
a = 'strings'
print(MyCounter(a).least_common())
print(MyCounter(a).most_common())
# Out:
# [('t', 1), ('r', 1), ('i', 1), ('n', 1), ('g', 1), ('s', 2)]
# [('s', 2), ('t', 1), ('r', 1), ('i', 1), ('n', 1), ('g', 1)]

# %% [markdown]
# ### Задание 4 (абстракция)

# %%
class Deposit:
    def __init__(self, percent, initial_amount, period_months,
                 capitalization=True, replenishment_allowed=False,
                 partial_withdrawal_allowed=False, auto_prolongation=False):
        self.percent = percent / 100  # годовая ставка, переводим в доли
        self.amount = initial_amount
        self.period = period_months
        self.capitalization = capitalization
        self.replenishment_allowed = replenishment_allowed
        self.partial_withdrawal_allowed = partial_withdrawal_allowed
        self.auto_prolongation = auto_prolongation
        self.opened = True
        self.start_month = 0

    def calculate_interest(self, months):
        """Рассчитать сумму через months месяцев без изменения вклада"""
        if self.capitalization:
            return self.amount * (1 + self.percent / 12) ** months
        else:
            return self.amount * (1 + self.percent / 12 * months)

    def wait(self, months):
        """Подождать months месяцев, начислить проценты"""
        if not self.opened:
            raise Exception("Депозит закрыт")
        if self.capitalization:
            self.amount = self.calculate_interest(months)
        else:
            self.amount = self.calculate_interest(months)  # для простоты считаем, что в конце срока получаем сумму с %
        self.start_month += months
        if self.start_month >= self.period:
            if self.auto_prolongation:
                self.start_month = 0
            else:
                self.opened = False

    def replenish(self, amount):
        if not self.replenishment_allowed:
            raise Exception("Пополнение запрещено")
        if not self.opened:
            raise Exception("Депозит закрыт")
        self.amount += amount

    def withdraw(self, amount):
        if not self.partial_withdrawal_allowed:
            raise Exception("Частичное снятие запрещено")
        if not self.opened:
            raise Exception("Депозит закрыт")
        if amount > self.amount:
            raise Exception("Недостаточно средств")
        self.amount -= amount

    def close(self):
        self.opened = False
        return self.amount
